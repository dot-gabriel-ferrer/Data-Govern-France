# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from os import walk

# %%
# get filenames with walk
f = []
for (dirpath, dirnames, filenames) in walk('collision_data/'):
    f.extend(filenames)
    break

# %%
f
# Out:
# ['vehicules_2009.csv',
#  'vehicules_2008.csv',
#  'vehicules-2017.csv',
#  'vehicules-2018.csv',
#  'vehicules-2019.csv',
#  'vehicules-2020.csv',
#  'vehicules_2005.csv',
#  'vehicules_2011.csv',
#  'vehicules_2010.csv',
#  'vehicules_2012.csv',
#  'vehicules_2006.csv',
#  'vehicules_2007.csv',
#  'vehicules_2013.csv',
#  'vehicules_2016.csv',
#  'vehicules_2014.csv',
#  'vehicules_2015.csv']

# %%
# read dataframe in csv with pandas
df = []
for file in f:
    df.append(pd.read_csv('collision_data/' + file))

# %%
# join dataframes
df = pd.concat(df)

# %%
df
# Out:
#             Num_Acc  senc  catv  occutc  obs  obsm  choc  manv num_veh  \
# 0      2.009000e+11   0.0  13.0     0.0  0.0   1.0   2.0   1.0     A01
# 1      2.009000e+11   0.0   7.0     0.0  0.0   2.0   2.0   1.0     B02
# 2      2.009000e+11   0.0   7.0     0.0  0.0   2.0   5.0  13.0     A01
# 3      2.009000e+11   0.0  10.0     0.0  0.0   2.0   2.0  15.0     A01
# 4      2.009000e+11   0.0  33.0     0.0  0.0   2.0   8.0   1.0     B02
# ...             ...   ...   ...     ...  ...   ...   ...   ...     ...
# 99773  2.015001e+11   1.0   7.0     0.0  0.0   2.0   1.0  17.0     A01
# 99774  2.015001e+11   1.0  30.0     0.0  0.0   2.0   1.0   1.0     B01
# 99775  2.015001e+11   0.0   7.0     0.0  0.0   1.0   2.0   1.0     A01
# 99776  2.015001e+11   0.0  30.0     0.0  0.0   2.0   1.0   1.0     A01
# 99777  2.015001e+11   0.0  10.0     0.0  0.0   9.0   4.0   1.0     B01
#
#       Num_Acc;"id_vehicule";"num_veh";"senc";"catv";"obs";"obsm";"choc";"manv";"motor";"occutc"
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 99773                                                NaN
# 99774                                                NaN
# 99775                                                NaN
# 99776                                                NaN
# 99777                                                NaN
#
# [1817587 rows x 10 columns]
